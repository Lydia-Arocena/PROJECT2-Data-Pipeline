# %%
import requests

# %% [markdown]
# ## Para múltiples parámetros a la vez
# El problema de esto es que no me esta pillando la fecha

# %%
url2 = 'https://ironhack_garca:72yMBpXR1Kcrl@api.meteomatics.com/find_station?location=47.3,9.3&startdate=2021-01-01T00Z&enddate=2021-01-20T00Z&parameters=t_2m:C,wind_speed_10m:ms' # aqui estoy sacando la temepratura y el viento. Puedes sacar humedad,nubes etc
# para saber que parámetros quieres incluir meteomatics.com/en/api/faq/#where_weather_data_from en el lado de la izquierda. 
res2 = requests.get(url2)
res2
# Out:
# <Response [200]>

# %%
res2.content
# Out:
# b'Station Category;Station Type;ID Hash;WMO ID;Alternative IDs;Name;Location Lat,Lon;Elevation;Start Date;End Date;Horizontal Distance;Vertical Distance;Effective Distance\nSYNOP;SYNO;631101226;066890;HOE;H\xc3\xb6rnli;47.3709,8.94164;1133m;2017-02-28T23:00:00Z;2021-11-06T11:50:00Z;28161.9;41;34508.7\nSYNOP;SYNA;96335824;066890;HOE;H\xc3\xb6rnli;47.3709,8.94164;1133m;2017-01-01T00:00:00Z;2021-11-06T11:00:00Z;28161.9;41;34508.7\nSYNOP;SYNA;847097565;113040;;Brand;47.1,9.73333;1040m;2017-01-01T00:00:00Z;2021-11-06T11:00:00Z;39620.7;-52;47670.3\nSYNOP;SYNO;4103067262;066820;ELM;Elm;46.9237,9.17535;958m;2017-02-28T23:00:00Z;2021-11-06T11:50:00Z;42935.5;-134;63678.6\nSYNOP;SYNA;1688195973;066820;ELM;Elm;46.9237,9.17535;958m;2017-01-01T00:00:00Z;2021-11-06T11:00:00Z;42935.5;-134;63678.6\nSYNOP;SYNO;4102201240;066810;STG;St. Gallen;47.4255,9.39853;776m;2017-02-28T23:00:00Z;2021-11-06T11:50:00Z;15819.9;-316;64736.3\nSYNOP;SYNA;4086087649;066810;STG;St. Gallen;47.4255,9.39853;776m;2017-01-01T
# ...

# %%
res2.headers
# Out:
# {'Date': 'Sat, 06 Nov 2021 12:01:39 GMT', 'Server': 'Apache', 'Content-Length': '8710', 'Content-Type': 'text/csv; charset=utf-8', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Methods': 'GET,POST,OPTIONS', 'Access-Control-Allow-Headers': 'Origin, X-Requested-With, Content-Type, Accept, Authorization', 'Access-Control-Max-Age': '7200', 'Vary': 'Origin'}

# %% [markdown]
# ## Sacar las coordenadas de una ciudad

# %%
ciudad = "Madrid"

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="puedesponerloquequieras")
location = geolocator.geocode("Madrid") # le pasamos la localización que queramos
print((location.latitude, location.longitude)) # sacamos la latitud y la longitud
# Out:
# (40.4167047, -3.7035825)

# %% [markdown]
# Lo ideal sería que te crearas una función que te devolviera las coordendas de cada una de tus ciudades. Esto ya te lo dejo a ti 😉
