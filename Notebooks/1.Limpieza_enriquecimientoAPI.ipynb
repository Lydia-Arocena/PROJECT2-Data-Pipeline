# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import sys
sys.path.append('../')
import src.apis_functions as af

# %%
df = pd.read_csv("../data/City_Quality_of_Life_Dataset.csv", index_col = 0)

# %%
df.sample()
# Out:
#     UA_Name UA_Country   UA_Continent  Housing  Cost of Living  Startups  \
# 198   Quito    Ecuador  South America   9.0165           7.822    2.8575
#
#      Venture Capital  Travel Connectivity  Commute  Business Freedom  Safety  \
# 198              0.0                 0.89  4.78925          3.021333   6.969
#
#      Healthcare  Education  Environmental Quality  Economy  Taxation  \
# 198    6.406333        0.0                4.17625   3.8855     7.514
#
#      Internet Access  Leisure & Culture  Tolerance  Outdoors
# 198           3.4815             4.8015     8.8265       5.5

# %%
df.columns
# Out:
# Index(['UA_Name', 'UA_Country', 'UA_Continent', 'Housing', 'Cost of Living',
#        'Startups', 'Venture Capital', 'Travel Connectivity', 'Commute',
#        'Business Freedom', 'Safety', 'Healthcare', 'Education',
#        'Environmental Quality', 'Economy', 'Taxation', 'Internet Access',
#        'Leisure & Culture', 'Tolerance', 'Outdoors'],
#       dtype='object')

# %% [markdown]
# ### 1. Unuseful columns are deleted :

# %%
df.drop(["Startups", "Venture Capital", "Travel Connectivity", "Business Freedom", "Tolerance"], axis=1, inplace=True)

# %%
df.sample()
# Out:
#     UA_Name UA_Country UA_Continent  Housing  Cost of Living  Commute  Safety  \
# 123  Krakow     Poland       Europe   8.4245           8.509    5.629  8.5215
#
#      Healthcare  Education  Environmental Quality  Economy  Taxation  \
# 123       6.854     4.6625                  4.802   4.7615     5.097
#
#      Internet Access  Leisure & Culture  Outdoors
# 123           5.7875               7.84    4.3085

# %%
df.shape
# Out:
# (266, 15)

# %% [markdown]
# ### 2. Renaming some columns:

# %%
new_columns = {'UA_Name': 'City', 'UA_Country': 'Country', 'UA_Continent': 'Continent'}

df.rename(columns=new_columns,inplace=True)

# %%
df.sample()
# Out:
#       City Country Continent  Housing  Cost of Living  Commute  Safety  \
# 244  Tokyo   Japan      Asia    5.657           3.431   6.0075    10.0
#
#      Healthcare  Education  Environmental Quality  Economy  Taxation  \
# 244    8.826333     6.9805                5.95575   3.7235     6.033
#
#      Internet Access  Leisure & Culture  Outdoors
# 244            4.835              9.342    6.5225

# %% [markdown]
# ### 3. Creating a new column called "Average Score" which is the mean of all the columns.

# %%
df["Average Score"]=df.mean(axis=1)
# Out:
# <ipython-input-10-083e61cc0b4b>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df["Average Score"]=df.mean(axis=1)

# %%
df.head()
# Out:
#           City       Country      Continent  Housing  Cost of Living  Commute  \
# 0       Aarhus       Denmark         Europe   6.1315           4.015  6.31175
# 1     Adelaide     Australia        Oceania   6.3095           4.692  5.33625
# 2  Albuquerque    New Mexico  North America   7.2620           6.059  5.05575
# 3       Almaty    Kazakhstan           Asia   9.2820           9.333  5.87125
# 4    Amsterdam   Netherlands         Europe   3.0530           3.824  6.11850
#
#    Safety  Healthcare  Education  Environmental Quality  Economy  Taxation  \
# 0  9.6165    8.704333     5.3665                7.63300   4.8865    5.0680
# 1  7.9260    7.936667     5.1420                8.33075   6.0695    4.5885
# 2  1.3435    6.430000     4.1520                7.31950   6.5145    4.3460
# 3  7.3090    4.545667     2.2830                3.85675   5.2690    8.5220
# 4  8.5035    7.907333     6.1800                7.59725   5.0530    4.9550
#
#    Internet Access  Leisure & Culture  Outdoors  Average Score
# 0            8.373             3.1870    4.1300       6.118590
# 1            4.341             4.3285    5.5310       5.877639
# 2            5.396             4.8900    3.5155       5.190313
# 3            2.886             2.9370    5.5000       5.632889
# 4            4.523             8.8740    5.3070       5.991299

# %% [markdown]
# ### 4. Enriching my dataframe by API:

# %%
df['Air Quality']=df.City.apply(af.getquality)

# %%
df.head()
# Out:
#           City       Country      Continent  Housing  Cost of Living  Commute  \
# 0       Aarhus       Denmark         Europe   6.1315           4.015  6.31175
# 1     Adelaide     Australia        Oceania   6.3095           4.692  5.33625
# 2  Albuquerque    New Mexico  North America   7.2620           6.059  5.05575
# 3       Almaty    Kazakhstan           Asia   9.2820           9.333  5.87125
# 4    Amsterdam   Netherlands         Europe   3.0530           3.824  6.11850
#
#    Safety  Healthcare  Education  Environmental Quality  Economy  Taxation  \
# 0  9.6165    8.704333     5.3665                7.63300   4.8865    5.0680
# 1  7.9260    7.936667     5.1420                8.33075   6.0695    4.5885
# 2  1.3435    6.430000     4.1520                7.31950   6.5145    4.3460
# 3  7.3090    4.545667     2.2830                3.85675   5.2690    8.5220
# 4  8.5035    7.907333     6.1800                7.59725   5.0530    4.9550
#
#    Internet Access  Leisure & Culture  Outdoors  Average Score Air Quality
# 0            8.373             3.1870    4.1300       6.118590         NaN
# 1            4.341             4.3285    5.5310       5.877639          44
# 2            5.396             4.8900    3.5155       5.190313          25
# 3            2.886             2.9370    5.5000       5.632889          65
# 4            4.523             8.8740    5.3070       5.991299          53

# %%
df['Air Quality Level']=df["Air Quality"].apply(af.quality_level)

# %%
df.head()
# Out:
#           City       Country      Continent  Housing  Cost of Living  Commute  \
# 0       Aarhus       Denmark         Europe   6.1315           4.015  6.31175
# 1     Adelaide     Australia        Oceania   6.3095           4.692  5.33625
# 2  Albuquerque    New Mexico  North America   7.2620           6.059  5.05575
# 3       Almaty    Kazakhstan           Asia   9.2820           9.333  5.87125
# 4    Amsterdam   Netherlands         Europe   3.0530           3.824  6.11850
#
#    Safety  Healthcare  Education  Environmental Quality  Economy  Taxation  \
# 0  9.6165    8.704333     5.3665                7.63300   4.8865    5.0680
# 1  7.9260    7.936667     5.1420                8.33075   6.0695    4.5885
# 2  1.3435    6.430000     4.1520                7.31950   6.5145    4.3460
# 3  7.3090    4.545667     2.2830                3.85675   5.2690    8.5220
# 4  8.5035    7.907333     6.1800                7.59725   5.0530    4.9550
#
#    Internet Access  Leisure & Culture  Outdoors  Average Score Air Quality  \
# 0            8.373             3.1870    4.1300       6.118590         NaN
# 1            4.341             4.3285    5.5310       5.877639          44
# 2            5.396             4.8900    3.5155       5.190313          25
# 3            2.886             2.9370    5.5000       5.632889          65
# 4            4.523             8.8740    5.3070       5.991299          53
#
#   Air Quality Level
# 0               NaN
# 1              Good
# 2              Good
# 3          Moderate
# 4          Moderate

# %%
df.to_csv("../data/final.csv")
